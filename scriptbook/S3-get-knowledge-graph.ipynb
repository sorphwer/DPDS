# %%
#THIS NOTEBOOK WILL USE INTERNET API TO GET A KNOWLEDGE GRAPH OF A GIVEN ENTITY
#IT NEED TO CONNECT TO DB TO FETCH A EXISTED TAG LIST
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from neo4j import GraphDatabase, basic_auth
from neo4j.exceptions import Neo4jError
import neo4j.time
import csv
import json
import time
import os
from flask_restful_swagger_2 import Api, swagger, Schema


def cprint(content,module='DEBUG',*args):
    if args:
        print('\033[1;32;43m ['+module+'] \033[0m '+ content + '\033[1;35m' +str(args) +' \033[0m' + time.strftime(" |%Y-%m-%d %H:%M:%S|", time.localtime()) )
    else:
        print('\033[1;32;43m ['+module+'] \033[0m '+ content + time.strftime(" |%Y-%m-%d %H:%M:%S|", time.localtime()))

        
DATABASE_USERNAME="neo4j"
DATABASE_PASSWORD="spade-discounts-switch"
DATABASE_URL="bolt://localhost:7687"
DATA_FILE_PATH = 'dev-to-articles.csv'

def db_fetch_all_tags(session):
    '''
    Fetch all nodes with label 'Tag'
    Args:
        session: db session,driver.session()
    Return:
        Cypher result, all nodes with label 'Tag'
    '''
    def _cypher(tx):
        return list(tx.run(
        '''
        MATCH (n:Tag)-[:HAS_TAG]-(ARTICLE) RETURN DISTINCT n
        '''
        ))
    result = session.read_transaction(_cypher)
    cprint(str(len(result))+'record fetched','DB')
    return result       
def serialize_tag(tag):
    return{
        'name':tag['name'],
        'keywords_for_search':tag['keywords_for_search']
    }


def db_create_subsume_relation(session,parent_tag,child_tag):
    '''
    Create relation: (parent_tag)-[SUBSUME]->(child_tag)
    Args:
        session: db session,driver.session()
        parent_tag: string, name of tag
        child_tag: string, name of tag
    Return:
        Cypher result of created relation
    '''
    if not parent_tag:
        return 'parent tag is empty'
    if not child_tag:
        return 'child tag is empty'
    def _cypher(tx,parent_tag,child_tag):
        return list(tx.run(
        '''
        MERGE (n:Tag {name:$parent_tag})
        MERGE (m:Tag {name:$child_tag})
        MERGE (n)-[subsume:SUBSUME]-> (m)
        RETURN subsume
        ''',{'parent_tag': parent_tag , 'child_tag': child_tag}
        ))
    result = session.write_transaction(_cypher,parent_tag,child_tag)
    return result

def db_add_keywords_to_tag(session,tag_name,keyword):
    '''
    Update attribution 'keywords' of Tag node
    Args:
        session: db session,driver.session()
        tag_name: string of tag name
        keyword: string of keyword to add
    Return:
        Cypher result of updated node
    Error Return:
        String with specific info
    '''
    
    if not keyword:
        return 'keyword is empty'
    if not tag_name:
        return 'tag name is empty'
    else:
        keyword = keyword.replace("+", " ")
    def _cypher_get_node(tx,tag_name):
        return list(tx.run(
        '''
        MATCH (n:Tag {name:$tag_name})
        RETURN n
        ''',{'tag_name':tag_name}
        ))
    def _cypher_update_node(tx,tag_name,new_keyword):
        return list(tx.run(
        '''
        MATCH (n:Tag {name:$tag_name})
        SET n.keywords_for_search = $keyword
        RETURN n
        ''',{'tag_name' : tag_name,'keyword' : new_keyword}
        ))
    
    tag_node = session.read_transaction(_cypher_get_node,tag_name)

    if tag_node:
        old_keywords = serialize_tag(tag_node[0]['n'])['keywords_for_search']
    else:
        return 'No such Tag node'
    if (old_keywords):
        if keyword in old_keywords:
            return 'keyword is already logged'
        new_keyword = old_keywords+'+'+keyword
    else:
        new_keyword = keyword

    result = session.write_transaction(_cypher_update_node,tag_name,new_keyword)
    return result

    


    
driver = GraphDatabase.driver(DATABASE_URL, auth=basic_auth(DATABASE_USERNAME, str(DATABASE_PASSWORD)))
with driver.session() as session: 
    tag_list = db_fetch_all_tags(session)
    session.close()
    
#EXPORT VAR : tag_list
# Out:
#  [DB]  496record fetched |2021-04-26 11:41:00|

# %%
#QUERY FOR A SINGLE TAG
#THIS CAN RUN SEPERATELY IF REMAP VARIABLE 'tag_list'
#IMPUT: tag_list, db driver
from SPARQLWrapper import SPARQLWrapper, JSON
def is_all_chinese(strs):
    for _char in strs:
        if not '\u4e00' <= _char <= '\u9fa5':
            return False
    return True
def get_query(tag):
    '''
    Args: string, name of entity
    Return: string, url for wikidata

    '''
    language_code = 'en'
    cprint('Generating query with:'+tag,'WIKIDATA')
    if (is_all_chinese(tag)):
        language_code = 'zh'
            
    query = '''SELECT ?item ?itemLabel ?P1 ?P1Label ?P2 ?P2Label ?P3 ?P3Label ?item_zh ?P1Label_zh ?P2Label_zh ?P3Label_zh 
       WHERE {?item ?label "'''+tag+'''"@'''+language_code+'''. 
       # ?article schema:about ?item .?article schema:inLanguage "en" .
       # ?article schema:isPartOf <https://en.wikipedia.org/>. 
       # ?item (wdt:P279|wdt:P361|wdt:P101|wdt:P425|wdt:P31|wdt:P277) ?P1.
       OPTIONAL { ?P1 (wdt:P279|wdt:P361|wdt:P101|wdt:P425|wdt:P31|wdt:P277) ?P2. }
       OPTIONAL { ?P2 (wdt:P279|wdt:P361|wdt:P101|wdt:P425|wdt:P31|wdt:P277) ?P3. }
       OPTIONAL {?item rdfs:label ?item_zh filter (lang(?item_zh) = "zh-cn")}.
       OPTIONAL {?P1 rdfs:label ?P1Label_zh filter (lang(?P1Label_zh) = "zh-cn")}.
       OPTIONAL {?P2 rdfs:label ?P2Label_zh filter (lang(?P2Label_zh) = "zh-cn")}.
       OPTIONAL {?P3 rdfs:label ?P3Label_zh filter (lang(?P3Label_zh) = "zh-cn")}.
       SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
      }'''
    return query

def get_results(query, endpoint_url="https://query.wikidata.org/sparql", ):
    '''
    Get wikidata query result
    Args:
        endpoint_url : "https://query.wikidata.org/sparql"
        query: query script
        tag: source tag
    Return:
    [
           {
          "item":"http://www.wikidata.org/entity/Q6859454",
          "itemLabel":"web developer",
          "P1":"http://www.wikidata.org/entity/Q183888",
          "P1Label":"software developer",
          "P2":"http://www.wikidata.org/entity/Q4164871",
          "P2Label":"position",
          "P3":"http://www.wikidata.org/entity/Q16686448",
          "P3Label":"artificial entity",
          "P1Label_zh":"软件开发者",
          "P2Label_zh":"职位",
          "P3Label_zh":"人造客体"
           },
           ...
   ]
    '''
    user_agent = "WDQS-Example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
  #  user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36"
    #adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    try:
        res = sparql.query().convert()
        cprint(str(len(res['results']['bindings']))+' records fetched','WIKIDATA')
        if len(res['results']['bindings']) == 0:
            return False
        return res
    except: 
        time.sleep(1)
        cprint('Query failed:','WIKIDATA')
        #No distinct exception parameter for HTTPError from urllib2  & EndPointInternalError
        #source code : https://rdflib.dev/sparqlwrapper/doc/1.6.0/SPARQLWrapper.Wrapper-pysrc.html
        #guidance: https://sparqlwrapper.readthedocs.io/en/latest/main.html
        return False
    
def file_write_log(path,info):
    with open(path, mode='a+',encoding="utf-8") as file_a:
        file_a.write( str(info) + time.strftime(" |%Y-%m-%d %H:%M:%S|", time.localtime()) + '\n')
    file_a.close()


def db_generate_tag_tree(session,tag_list):
    '''
    Args: return value from db_fetch_all_tags(session)
    
    Return: 1

    ''' 
    counter = 90
    tag_number = len(tag_list)
    for tag in tag_list[90:]:
        tag_name = serialize_tag(tag['n'])['name']
        #request wikidata with tag_name
        wiki_results = get_results(get_query(tag_name))
        if not wiki_results:
            file_write_log('wikidata-error-log.txt',tag_name)
            continue
        time.sleep( 5 )
        for res in wiki_results['results']['bindings']:
            #init origin tag
            db_add_keywords_to_tag(session,tag_name,tag_name)
            #handle itemLabel col
            if('itemLabel' in res):
                db_add_keywords_to_tag(session,tag_name,res['itemLabel']['value'])
            #handle P1Label col
            if('P1Label' in res):
                db_create_subsume_relation(session,res['P1Label']['value'],tag_name)
                db_add_keywords_to_tag(session,res['P1Label']['value'],res['P1Label']['value'])
            #handle P2Label col
            if('P2Label' in res):
                db_create_subsume_relation(session,res['P2Label']['value'],res['P1Label']['value'])
                db_add_keywords_to_tag(session,res['P2Label']['value'],res['P2Label']['value'])
            #handle P3Label col
            if('P3Label' in res):
                db_create_subsume_relation(session,res['P3Label']['value'],res['P2Label']['value'])
                db_add_keywords_to_tag(session,res['P3Label']['value'],res['P3Label']['value'])
            #handle item_zh col
            if('item_zh' in res):
                db_add_keywords_to_tag(session,tag_name,res['item_zh']['value'])
            #handle P1Label_zh col
            if('P1Label_zh' in res):
                db_add_keywords_to_tag(session,res['P1Label']['value'],res['P1Label_zh']['value'])
            #handle P2Label_zh col
            if('P2Label_zh' in res):
                db_add_keywords_to_tag(session,res['P2Label']['value'],res['P2Label_zh']['value'])
            #handle P3Label_zh col
            if('P3Label_zh' in res):
                db_add_keywords_to_tag(session,res['P3Label']['value'],res['P3Label_zh']['value'])
        cprint('Knowledge Graph Built: '+tag_name+' ['+str(counter)+'/'+str(tag_number)+']', 'DB')
        counter+=1
    return tag_list

with driver.session() as session: 
    db_generate_tag_tree(session,tag_list)
    session.close()
# Out:
#  [WIKIDATA]  Generating query with:terminal |2021-04-26 12:30:14|
#  [WIKIDATA]  Query failed: |2021-04-26 12:31:17|
#  [WIKIDATA]  Generating query with:microservices |2021-04-26 12:31:17|
#  [WIKIDATA]  15 records fetched |2021-04-26 12:31:18|
#  [DB]  Knowledge Graph Built: microservices [90/496] |2021-04-26 12:31:24|
#  [WIKIDATA]  Generating query with:rxjs |2021-04-26 12:31:24|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:31:25|
#  [WIKIDATA]  Generating query with:reactiveprogramming |2021-04-26 12:31:25|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:31:27|
#  [WIKIDATA]  Generating query with:nextjs |2021-04-26 12:31:27|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:31:28|
#  [WIKIDATA]  Generating query with:aws |2021-04-26 12:31:28|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:31:29|
#  [WIKIDATA]  Generating query with:dashboards |2021-04-26 12:31:29|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:31:30|
#  [WIKIDATA]  Generating query with:bootstrap |2021-04-26 12:31:30|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:31:32|
#  [WIKIDATA]  Generating query with:rust |2021-04-26 12:31:32|
#  [WIKIDATA]  43 records fetched |2021-04-26 12:31:33|
#  [DB]  Knowledge Graph Built: rust [91/496] |2021-04-26 12:31:40|
#  [WIKIDATA]  Generating query with:php |2021-04-26 12:31:40|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:31:41|
#  [WIKIDATA]  Generating query with:bash |2021-04-26 12:31:41|
#  [WIKIDATA]  Query failed: |2021-04-26 12:32:44|
#  [WIKIDATA]  Generating query with:cloud |2021-04-26 12:32:44|
#  [WIKIDATA]  36 records fetched |2021-04-26 12:32:46|
#  [DB]  Knowledge Graph Built: cloud [92/496] |2021-04-26 12:32:52|
#  [WIKIDATA]  Generating query with:youtube |2021-04-26 12:32:52|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:32:53|
#  [WIKIDATA]  Generating query with:mlhgrad |2021-04-26 12:32:53|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:32:54|
#  [WIKIDATA]  Generating query with:localhackday |2021-04-26 12:32:55|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:32:56|
#  [WIKIDATA]  Generating query with:challenge |2021-04-26 12:32:56|
#  [WIKIDATA]  24 records fetched |2021-04-26 12:32:58|
#  [DB]  Knowledge Graph Built: challenge [93/496] |2021-04-26 12:33:03|
#  [WIKIDATA]  Generating query with:animation |2021-04-26 12:33:03|
#  [WIKIDATA]  42 records fetched |2021-04-26 12:33:05|
#  [DB]  Knowledge Graph Built: animation [94/496] |2021-04-26 12:33:12|
#  [WIKIDATA]  Generating query with:development |2021-04-26 12:33:12|
#  [WIKIDATA]  52 records fetched |2021-04-26 12:33:14|
#  [DB]  Knowledge Graph Built: development [95/496] |2021-04-26 12:33:20|
#  [WIKIDATA]  Generating query with:remote |2021-04-26 12:33:20|
#  [WIKIDATA]  5 records fetched |2021-04-26 12:33:21|
#  [DB]  Knowledge Graph Built: remote [96/496] |2021-04-26 12:33:27|
#  [WIKIDATA]  Generating query with:codequality |2021-04-26 12:33:27|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:28|
#  [WIKIDATA]  Generating query with:devjournal |2021-04-26 12:33:28|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:29|
#  [WIKIDATA]  Generating query with:books |2021-04-26 12:33:29|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:30|
#  [WIKIDATA]  Generating query with:cli |2021-04-26 12:33:30|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:32|
#  [WIKIDATA]  Generating query with:mac |2021-04-26 12:33:32|
#  [WIKIDATA]  14 records fetched |2021-04-26 12:33:33|
#  [DB]  Knowledge Graph Built: mac [97/496] |2021-04-26 12:33:38|
#  [WIKIDATA]  Generating query with:auth |2021-04-26 12:33:38|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:40|
#  [WIKIDATA]  Generating query with:jwt |2021-04-26 12:33:40|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:41|
#  [WIKIDATA]  Generating query with:tenseijs |2021-04-26 12:33:41|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:42|
#  [WIKIDATA]  Generating query with:responsivewebdesign |2021-04-26 12:33:42|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:43|
#  [WIKIDATA]  Generating query with:webapp |2021-04-26 12:33:43|
#  [WIKIDATA]  6 records fetched |2021-04-26 12:33:45|
#  [DB]  Knowledge Graph Built: webapp [98/496] |2021-04-26 12:33:50|
#  [WIKIDATA]  Generating query with:pwa |2021-04-26 12:33:50|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:51|
#  [WIKIDATA]  Generating query with:webmonetization |2021-04-26 12:33:51|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:52|
#  [WIKIDATA]  Generating query with:gftwhackathon |2021-04-26 12:33:52|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:53|
#  [WIKIDATA]  Generating query with:http |2021-04-26 12:33:53|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:33:55|
#  [WIKIDATA]  Generating query with:cybersecurity |2021-04-26 12:33:55|
#  [WIKIDATA]  5 records fetched |2021-04-26 12:33:56|
#  [DB]  Knowledge Graph Built: cybersecurity [99/496] |2021-04-26 12:34:01|
#  [WIKIDATA]  Generating query with:hiring |2021-04-26 12:34:01|
#  [WIKIDATA]  58 records fetched |2021-04-26 12:34:04|
#  [DB]  Knowledge Graph Built: hiring [100/496] |2021-04-26 12:34:10|
#  [WIKIDATA]  Generating query with:hacktoberfest |2021-04-26 12:34:10|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:34:11|
#  [WIKIDATA]  Generating query with:questions |2021-04-26 12:34:11|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:34:12|
#  [WIKIDATA]  Generating query with:jobsearching |2021-04-26 12:34:12|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:34:14|
#  [WIKIDATA]  Generating query with:interviewing |2021-04-26 12:34:14|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:34:15|
#  [WIKIDATA]  Generating query with:filter |2021-04-26 12:34:15|
#  [WIKIDATA]  61 records fetched |2021-04-26 12:34:17|
#  [DB]  Knowledge Graph Built: filter [101/496] |2021-04-26 12:34:23|
#  [WIKIDATA]  Generating query with:management |2021-04-26 12:34:23|
#  [WIKIDATA]  56 records fetched |2021-04-26 12:34:26|
#  [DB]  Knowledge Graph Built: management [102/496] |2021-04-26 12:34:32|
#  [WIKIDATA]  Generating query with:graphql |2021-04-26 12:34:32|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:34:33|
#  [WIKIDATA]  Generating query with:privacy |2021-04-26 12:34:33|
#  [WIKIDATA]  24 records fetched |2021-04-26 12:34:35|
#  [DB]  Knowledge Graph Built: privacy [103/496] |2021-04-26 12:34:41|
#  [WIKIDATA]  Generating query with:ungoogle |2021-04-26 12:34:41|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:34:42|
#  [WIKIDATA]  Generating query with:degoogle |2021-04-26 12:34:42|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:34:43|
#  [WIKIDATA]  Generating query with:googlecloud |2021-04-26 12:34:43|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:34:44|
#  [WIKIDATA]  Generating query with:migrate |2021-04-26 12:34:44|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:34:46|
#  [WIKIDATA]  Generating query with:todayilearned |2021-04-26 12:34:46|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:34:47|
#  [WIKIDATA]  Generating query with:software |2021-04-26 12:34:47|
#  [WIKIDATA]  7243 records fetched |2021-04-26 12:34:59|
#  [DB]  Knowledge Graph Built: software [104/496] |2021-04-26 12:36:37|
#  [WIKIDATA]  Generating query with:machinelearning |2021-04-26 12:36:37|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:36:39|
#  [WIKIDATA]  Generating query with:handsfree |2021-04-26 12:36:39|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:36:40|
#  [WIKIDATA]  Generating query with:a11y |2021-04-26 12:36:40|
#  [WIKIDATA]  58 records fetched |2021-04-26 12:36:42|
#  [DB]  Knowledge Graph Built: a11y [105/496] |2021-04-26 12:36:48|
#  [WIKIDATA]  Generating query with:blackfriday |2021-04-26 12:36:48|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:36:49|
#  [WIKIDATA]  Generating query with:deals |2021-04-26 12:36:49|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:36:50|
#  [WIKIDATA]  Generating query with:discuss |2021-04-26 12:36:50|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:36:52|
#  [WIKIDATA]  Generating query with:keylogger |2021-04-26 12:36:52|
#  [WIKIDATA]  22 records fetched |2021-04-26 12:36:53|
#  [DB]  Knowledge Graph Built: keylogger [106/496] |2021-04-26 12:36:59|
#  [WIKIDATA]  Generating query with:coil |2021-04-26 12:36:59|
#  [WIKIDATA]  34 records fetched |2021-04-26 12:37:01|
#  [DB]  Knowledge Graph Built: coil [107/496] |2021-04-26 12:37:06|
#  [WIKIDATA]  Generating query with:tooling |2021-04-26 12:37:06|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:37:08|
#  [WIKIDATA]  Generating query with:tech |2021-04-26 12:37:08|
#  [WIKIDATA]  10 records fetched |2021-04-26 12:37:09|
#  [DB]  Knowledge Graph Built: tech [108/496] |2021-04-26 12:37:14|
#  [WIKIDATA]  Generating query with:oop |2021-04-26 12:37:14|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:37:16|
#  [WIKIDATA]  Generating query with:project |2021-04-26 12:37:16|
#  [WIKIDATA]  148 records fetched |2021-04-26 12:37:19|
#  [DB]  Knowledge Graph Built: project [109/496] |2021-04-26 12:37:26|
#  [WIKIDATA]  Generating query with:ideas |2021-04-26 12:37:26|
#  [WIKIDATA]  25 records fetched |2021-04-26 12:37:28|
#  [DB]  Knowledge Graph Built: ideas [110/496] |2021-04-26 12:37:34|
#  [WIKIDATA]  Generating query with:backend |2021-04-26 12:37:34|
#  [WIKIDATA]  11 records fetched |2021-04-26 12:37:36|
#  [DB]  Knowledge Graph Built: backend [111/496] |2021-04-26 12:37:42|
#  [WIKIDATA]  Generating query with:freelance |2021-04-26 12:37:42|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:37:43|
#  [WIKIDATA]  Generating query with:expressjs |2021-04-26 12:37:43|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:37:44|
#  [WIKIDATA]  Generating query with:framework |2021-04-26 12:37:44|
#  [WIKIDATA]  175 records fetched |2021-04-26 12:37:47|
#  [DB]  Knowledge Graph Built: framework [112/496] |2021-04-26 12:37:54|
#  [WIKIDATA]  Generating query with:personalgrowth |2021-04-26 12:37:54|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:37:56|
#  [WIKIDATA]  Generating query with:problemsolving |2021-04-26 12:37:56|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:37:57|
#  [WIKIDATA]  Generating query with:blog |2021-04-26 12:37:57|
#  [WIKIDATA]  228 records fetched |2021-04-26 12:38:00|
#  [DB]  Knowledge Graph Built: blog [113/496] |2021-04-26 12:38:08|
#  [WIKIDATA]  Generating query with:pdf |2021-04-26 12:38:08|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:38:10|
#  [WIKIDATA]  Generating query with:finance |2021-04-26 12:38:10|
#  [WIKIDATA]  94 records fetched |2021-04-26 12:38:12|
#  [DB]  Knowledge Graph Built: finance [114/496] |2021-04-26 12:38:19|
#  [WIKIDATA]  Generating query with:startup |2021-04-26 12:38:19|
#  [WIKIDATA]  25 records fetched |2021-04-26 12:38:20|
#  [DB]  Knowledge Graph Built: startup [115/496] |2021-04-26 12:38:26|
#  [WIKIDATA]  Generating query with:lifehacks |2021-04-26 12:38:26|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:38:27|
#  [WIKIDATA]  Generating query with:laravel |2021-04-26 12:38:27|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:38:28|
#  [WIKIDATA]  Generating query with:solid |2021-04-26 12:38:28|
#  [WIKIDATA]  39 records fetched |2021-04-26 12:38:30|
#  [DB]  Knowledge Graph Built: solid [116/496] |2021-04-26 12:38:36|
#  [WIKIDATA]  Generating query with:express |2021-04-26 12:38:36|
#  [WIKIDATA]  66 records fetched |2021-04-26 12:38:39|
#  [DB]  Knowledge Graph Built: express [117/496] |2021-04-26 12:38:45|
#  [WIKIDATA]  Generating query with:cpp |2021-04-26 12:38:45|
#  [WIKIDATA]  Query failed: |2021-04-26 12:39:47|
#  [WIKIDATA]  Generating query with:keyboard |2021-04-26 12:39:47|
#  [WIKIDATA]  69 records fetched |2021-04-26 12:39:49|
#  [DB]  Knowledge Graph Built: keyboard [118/496] |2021-04-26 12:39:55|
#  [WIKIDATA]  Generating query with:promises |2021-04-26 12:39:55|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:39:57|
#  [WIKIDATA]  Generating query with:testing |2021-04-26 12:39:57|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:39:58|
#  [WIKIDATA]  Generating query with:programmer |2021-04-26 12:39:58|
#  [WIKIDATA]  145 records fetched |2021-04-26 12:40:01|
#  [DB]  Knowledge Graph Built: programmer [119/496] |2021-04-26 12:40:07|
#  [WIKIDATA]  Generating query with:financialfreedom |2021-04-26 12:40:07|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:08|
#  [WIKIDATA]  Generating query with:headless |2021-04-26 12:40:08|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:10|
#  [WIKIDATA]  Generating query with:cms |2021-04-26 12:40:10|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:11|
#  [WIKIDATA]  Generating query with:100daysofcode |2021-04-26 12:40:11|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:12|
#  [WIKIDATA]  Generating query with:fullstack |2021-04-26 12:40:12|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:13|
#  [WIKIDATA]  Generating query with:statistics |2021-04-26 12:40:13|
#  [WIKIDATA]  91 records fetched |2021-04-26 12:40:16|
#  [DB]  Knowledge Graph Built: statistics [120/496] |2021-04-26 12:40:22|
#  [WIKIDATA]  Generating query with:mongodb |2021-04-26 12:40:22|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:23|
#  [WIKIDATA]  Generating query with:callbacks |2021-04-26 12:40:23|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:25|
#  [WIKIDATA]  Generating query with:ui |2021-04-26 12:40:25|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:26|
#  [WIKIDATA]  Generating query with:coding |2021-04-26 12:40:26|
#  [WIKIDATA]  30 records fetched |2021-04-26 12:40:28|
#  [DB]  Knowledge Graph Built: coding [121/496] |2021-04-26 12:40:33|
#  [WIKIDATA]  Generating query with:gamedev |2021-04-26 12:40:33|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:34|
#  [WIKIDATA]  Generating query with:writing |2021-04-26 12:40:34|
#  [WIKIDATA]  18 records fetched |2021-04-26 12:40:36|
#  [DB]  Knowledge Graph Built: writing [122/496] |2021-04-26 12:40:41|
#  [WIKIDATA]  Generating query with:webdesign |2021-04-26 12:40:41|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:43|
#  [WIKIDATA]  Generating query with:slides |2021-04-26 12:40:43|
#  [WIKIDATA]  3 records fetched |2021-04-26 12:40:44|
#  [DB]  Knowledge Graph Built: slides [123/496] |2021-04-26 12:40:49|
#  [WIKIDATA]  Generating query with:figma |2021-04-26 12:40:49|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:50|
#  [WIKIDATA]  Generating query with:microfrontends |2021-04-26 12:40:50|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:51|
#  [WIKIDATA]  Generating query with:micro |2021-04-26 12:40:51|
#  [WIKIDATA]  5 records fetched |2021-04-26 12:40:53|
#  [DB]  Knowledge Graph Built: micro [124/496] |2021-04-26 12:40:58|
#  [WIKIDATA]  Generating query with:layout2code |2021-04-26 12:40:58|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:40:59|
#  [WIKIDATA]  Generating query with:autocode |2021-04-26 12:40:59|
#  [WIKIDATA]  9 records fetched |2021-04-26 12:41:00|
#  [DB]  Knowledge Graph Built: autocode [125/496] |2021-04-26 12:41:07|
#  [WIKIDATA]  Generating query with:googlesheets |2021-04-26 12:41:07|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:41:09|
#  [WIKIDATA]  Generating query with:healthydebate |2021-04-26 12:41:09|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:41:10|
#  [WIKIDATA]  Generating query with:gitbash |2021-04-26 12:41:10|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:41:11|
#  [WIKIDATA]  Generating query with:gatsby |2021-04-26 12:41:11|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:41:12|
#  [WIKIDATA]  Generating query with:oauth |2021-04-26 12:41:12|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:41:13|
#  [WIKIDATA]  Generating query with:typography |2021-04-26 12:41:13|
#  [WIKIDATA]  Query failed: |2021-04-26 12:42:15|
#  [WIKIDATA]  Generating query with:hooks |2021-04-26 12:42:15|
#  [WIKIDATA]  8 records fetched |2021-04-26 12:42:17|
#  [DB]  Knowledge Graph Built: hooks [126/496] |2021-04-26 12:42:22|
#  [WIKIDATA]  Generating query with:animations |2021-04-26 12:42:22|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:42:23|
#  [WIKIDATA]  Generating query with:profile |2021-04-26 12:42:23|
#  [WIKIDATA]  24 records fetched |2021-04-26 12:42:24|
#  [DB]  Knowledge Graph Built: profile [127/496] |2021-04-26 12:42:30|
#  [WIKIDATA]  Generating query with:dashboard |2021-04-26 12:42:30|
#  [WIKIDATA]  59 records fetched |2021-04-26 12:42:33|
#  [DB]  Knowledge Graph Built: dashboard [128/496] |2021-04-26 12:42:39|
#  [WIKIDATA]  Generating query with:reactadmindashboard |2021-04-26 12:42:39|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:42:40|
#  [WIKIDATA]  Generating query with:reactadmin |2021-04-26 12:42:40|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:42:41|
#  [WIKIDATA]  Generating query with:webpack |2021-04-26 12:42:41|
#  [WIKIDATA]  14 records fetched |2021-04-26 12:42:42|
#  [DB]  Knowledge Graph Built: webpack [129/496] |2021-04-26 12:42:48|
#  [WIKIDATA]  Generating query with:icons |2021-04-26 12:42:48|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:42:49|
#  [WIKIDATA]  Generating query with:developertools |2021-04-26 12:42:49|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:42:50|
#  [WIKIDATA]  Generating query with:mapbox |2021-04-26 12:42:50|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:42:51|
#  [WIKIDATA]  Generating query with:upwork |2021-04-26 12:42:51|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:42:52|
#  [WIKIDATA]  Generating query with:shared |2021-04-26 12:42:52|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:42:53|
#  [WIKIDATA]  Generating query with:functions |2021-04-26 12:42:53|
#  [WIKIDATA]  45 records fetched |2021-04-26 12:42:55|
#  [DB]  Knowledge Graph Built: functions [130/496] |2021-04-26 12:43:01|
#  [WIKIDATA]  Generating query with:resume |2021-04-26 12:43:01|
#  [WIKIDATA]  7 records fetched |2021-04-26 12:43:02|
#  [DB]  Knowledge Graph Built: resume [131/496] |2021-04-26 12:43:08|
#  [WIKIDATA]  Generating query with:monolithic |2021-04-26 12:43:08|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:43:09|
#  [WIKIDATA]  Generating query with:jokes |2021-04-26 12:43:09|
#  [WIKIDATA]  2 records fetched |2021-04-26 12:43:10|
#  [DB]  Knowledge Graph Built: jokes [132/496] |2021-04-26 12:43:15|
#  [WIKIDATA]  Generating query with:workstations |2021-04-26 12:43:15|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:43:16|
#  [WIKIDATA]  Generating query with:emojis |2021-04-26 12:43:16|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:43:17|
#  [WIKIDATA]  Generating query with:lambda |2021-04-26 12:43:17|
#  [WIKIDATA]  26 records fetched |2021-04-26 12:43:19|
#  [DB]  Knowledge Graph Built: lambda [133/496] |2021-04-26 12:43:25|
#  [WIKIDATA]  Generating query with:serverless |2021-04-26 12:43:25|
#  [WIKIDATA]  Query failed: |2021-04-26 12:44:27|
#  [WIKIDATA]  Generating query with:c |2021-04-26 12:44:27|
#  [WIKIDATA]  74 records fetched |2021-04-26 12:44:29|
#  [DB]  Knowledge Graph Built: c [134/496] |2021-04-26 12:44:36|
#  [WIKIDATA]  Generating query with:azure |2021-04-26 12:44:36|
#  [WIKIDATA]  44 records fetched |2021-04-26 12:44:38|
#  [DB]  Knowledge Graph Built: azure [135/496] |2021-04-26 12:44:43|
#  [WIKIDATA]  Generating query with:interviewbit |2021-04-26 12:44:43|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:44:44|
#  [WIKIDATA]  Generating query with:scaleracademy |2021-04-26 12:44:44|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:44:46|
#  [WIKIDATA]  Generating query with:go |2021-04-26 12:44:46|
#  [WIKIDATA]  46 records fetched |2021-04-26 12:44:48|
#  [DB]  Knowledge Graph Built: go [136/496] |2021-04-26 12:44:53|
#  [WIKIDATA]  Generating query with:terraform |2021-04-26 12:44:53|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:44:54|
#  [WIKIDATA]  Generating query with:mobile |2021-04-26 12:44:54|
#  [WIKIDATA]  27 records fetched |2021-04-26 12:44:56|
#  [DB]  Knowledge Graph Built: mobile [137/496] |2021-04-26 12:45:02|
#  [WIKIDATA]  Generating query with:android |2021-04-26 12:45:02|
#  [WIKIDATA]  8 records fetched |2021-04-26 12:45:03|
#  [DB]  Knowledge Graph Built: android [138/496] |2021-04-26 12:45:08|
#  [WIKIDATA]  Generating query with:projects |2021-04-26 12:45:08|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:45:10|
#  [WIKIDATA]  Generating query with:organization |2021-04-26 12:45:10|
#  [WIKIDATA]  Query failed: |2021-04-26 12:46:12|
#  [WIKIDATA]  Generating query with:os |2021-04-26 12:46:12|
#  [WIKIDATA]  35 records fetched |2021-04-26 12:46:14|
#  [DB]  Knowledge Graph Built: os [139/496] |2021-04-26 12:46:19|
#  [WIKIDATA]  Generating query with:x86 |2021-04-26 12:46:19|
#  [WIKIDATA]  36 records fetched |2021-04-26 12:46:21|
#  [DB]  Knowledge Graph Built: x86 [140/496] |2021-04-26 12:46:27|
#  [WIKIDATA]  Generating query with:assembler |2021-04-26 12:46:27|
#  [WIKIDATA]  52 records fetched |2021-04-26 12:46:29|
#  [DB]  Knowledge Graph Built: assembler [141/496] |2021-04-26 12:46:35|
#  [WIKIDATA]  Generating query with:django |2021-04-26 12:46:35|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:46:36|
#  [WIKIDATA]  Generating query with:resources |2021-04-26 12:46:36|
#  [WIKIDATA]  14 records fetched |2021-04-26 12:46:38|
#  [DB]  Knowledge Graph Built: resources [142/496] |2021-04-26 12:46:43|
#  [WIKIDATA]  Generating query with:eslint |2021-04-26 12:46:43|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:46:44|
#  [WIKIDATA]  Generating query with:prettier |2021-04-26 12:46:44|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:46:46|
#  [WIKIDATA]  Generating query with:engineer |2021-04-26 12:46:46|
#  [WIKIDATA]  1551 records fetched |2021-04-26 12:46:52|
#  [DB]  Knowledge Graph Built: engineer [143/496] |2021-04-26 12:47:15|
#  [WIKIDATA]  Generating query with:crio |2021-04-26 12:47:15|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:47:17|
#  [WIKIDATA]  Generating query with:commandline |2021-04-26 12:47:17|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:47:18|
#  [WIKIDATA]  Generating query with:blockchain |2021-04-26 12:47:18|
#  [WIKIDATA]  Query failed: |2021-04-26 12:48:20|
#  [WIKIDATA]  Generating query with:mentalhealth |2021-04-26 12:48:20|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:48:21|
#  [WIKIDATA]  Generating query with:csharp |2021-04-26 12:48:21|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:48:23|
#  [WIKIDATA]  Generating query with:language |2021-04-26 12:48:23|
#  [WIKIDATA]  Query failed: |2021-04-26 12:49:25|
#  [WIKIDATA]  Generating query with:location |2021-04-26 12:49:25|
#  [WIKIDATA]  61 records fetched |2021-04-26 12:49:27|
#  [DB]  Knowledge Graph Built: location [144/496] |2021-04-26 12:49:33|
#  [WIKIDATA]  Generating query with:cheatsheet |2021-04-26 12:49:33|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:49:35|
#  [WIKIDATA]  Generating query with:webpush |2021-04-26 12:49:35|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:49:36|
#  [WIKIDATA]  Generating query with:pushnotifications |2021-04-26 12:49:36|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:49:37|
#  [WIKIDATA]  Generating query with:notifications |2021-04-26 12:49:37|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:49:38|
#  [WIKIDATA]  Generating query with:components |2021-04-26 12:49:38|
#  [WIKIDATA]  9 records fetched |2021-04-26 12:49:40|
#  [DB]  Knowledge Graph Built: components [145/496] |2021-04-26 12:49:45|
#  [WIKIDATA]  Generating query with:saas |2021-04-26 12:49:45|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:49:46|
#  [WIKIDATA]  Generating query with:cryptography |2021-04-26 12:49:46|
#  [WIKIDATA]  17 records fetched |2021-04-26 12:49:48|
#  [DB]  Knowledge Graph Built: cryptography [146/496] |2021-04-26 12:49:53|
#  [WIKIDATA]  Generating query with:betterprogrammer |2021-04-26 12:49:53|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:49:54|
#  [WIKIDATA]  Generating query with:debugging |2021-04-26 12:49:54|
#  [WIKIDATA]  23 records fetched |2021-04-26 12:49:56|
#  [DB]  Knowledge Graph Built: debugging [147/496] |2021-04-26 12:50:01|
#  [WIKIDATA]  Generating query with:dotnet |2021-04-26 12:50:01|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:02|
#  [WIKIDATA]  Generating query with:cdk |2021-04-26 12:50:02|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:04|
#  [WIKIDATA]  Generating query with:freecodecamp |2021-04-26 12:50:04|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:05|
#  [WIKIDATA]  Generating query with:es6 |2021-04-26 12:50:05|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:07|
#  [WIKIDATA]  Generating query with:womenintech |2021-04-26 12:50:07|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:08|
#  [WIKIDATA]  Generating query with:context |2021-04-26 12:50:08|
#  [WIKIDATA]  20 records fetched |2021-04-26 12:50:10|
#  [DB]  Knowledge Graph Built: context [148/496] |2021-04-26 12:50:15|
#  [WIKIDATA]  Generating query with:ide |2021-04-26 12:50:15|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:16|
#  [WIKIDATA]  Generating query with:webscraping |2021-04-26 12:50:16|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:18|
#  [WIKIDATA]  Generating query with:tailwind |2021-04-26 12:50:18|
#  [WIKIDATA]  3 records fetched |2021-04-26 12:50:19|
#  [DB]  Knowledge Graph Built: tailwind [149/496] |2021-04-26 12:50:24|
#  [WIKIDATA]  Generating query with:framermotion |2021-04-26 12:50:24|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:25|
#  [WIKIDATA]  Generating query with:twitch |2021-04-26 12:50:25|
#  [WIKIDATA]  10 records fetched |2021-04-26 12:50:27|
#  [DB]  Knowledge Graph Built: twitch [150/496] |2021-04-26 12:50:32|
#  [WIKIDATA]  Generating query with:courses |2021-04-26 12:50:32|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:33|
#  [WIKIDATA]  Generating query with:colour |2021-04-26 12:50:33|
#  [WIKIDATA]  55 records fetched |2021-04-26 12:50:35|
#  [DB]  Knowledge Graph Built: colour [151/496] |2021-04-26 12:50:41|
#  [WIKIDATA]  Generating query with:cicd |2021-04-26 12:50:41|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:42|
#  [WIKIDATA]  Generating query with:jobapplication |2021-04-26 12:50:42|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:44|
#  [WIKIDATA]  Generating query with:post |2021-04-26 12:50:44|
#  [WIKIDATA]  37 records fetched |2021-04-26 12:50:46|
#  [DB]  Knowledge Graph Built: post [152/496] |2021-04-26 12:50:51|
#  [WIKIDATA]  Generating query with:vim |2021-04-26 12:50:51|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:52|
#  [WIKIDATA]  Generating query with:vimtips |2021-04-26 12:50:52|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:50:54|
#  [WIKIDATA]  Generating query with:editor |2021-04-26 12:50:54|
#  [WIKIDATA]  934 records fetched |2021-04-26 12:50:59|
#  [DB]  Knowledge Graph Built: editor [153/496] |2021-04-26 12:51:16|
#  [WIKIDATA]  Generating query with:functional |2021-04-26 12:51:16|
#  [WIKIDATA]  16 records fetched |2021-04-26 12:51:17|
#  [DB]  Knowledge Graph Built: functional [154/496] |2021-04-26 12:51:23|
#  [WIKIDATA]  Generating query with:illustration |2021-04-26 12:51:23|
#  [WIKIDATA]  6 records fetched |2021-04-26 12:51:24|
#  [DB]  Knowledge Graph Built: illustration [155/496] |2021-04-26 12:51:29|
#  [WIKIDATA]  Generating query with:fundamentals |2021-04-26 12:51:29|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:51:31|
#  [WIKIDATA]  Generating query with:valerie |2021-04-26 12:51:31|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:51:32|
#  [WIKIDATA]  Generating query with:webassembly |2021-04-26 12:51:32|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:51:33|
#  [WIKIDATA]  Generating query with:webapps |2021-04-26 12:51:33|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:51:34|
#  [WIKIDATA]  Generating query with:ddd |2021-04-26 12:51:34|
#  [WIKIDATA]  21 records fetched |2021-04-26 12:51:36|
#  [DB]  Knowledge Graph Built: ddd [156/496] |2021-04-26 12:51:41|
#  [WIKIDATA]  Generating query with:salary |2021-04-26 12:51:41|
#  [WIKIDATA]  16 records fetched |2021-04-26 12:51:43|
#  [DB]  Knowledge Graph Built: salary [157/496] |2021-04-26 12:51:48|
#  [WIKIDATA]  Generating query with:firstyearincode |2021-04-26 12:51:48|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:51:50|
#  [WIKIDATA]  Generating query with:gofiber |2021-04-26 12:51:50|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:51:51|
#  [WIKIDATA]  Generating query with:psychology |2021-04-26 12:51:51|
#  [WIKIDATA]  26 records fetched |2021-04-26 12:51:52|
#  [DB]  Knowledge Graph Built: psychology [158/496] |2021-04-26 12:51:58|
#  [WIKIDATA]  Generating query with:impostorsyndrome |2021-04-26 12:51:58|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:51:59|
#  [WIKIDATA]  Generating query with:sass |2021-04-26 12:51:59|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:52:01|
#  [WIKIDATA]  Generating query with:twitter |2021-04-26 12:52:01|
#  [WIKIDATA]  3 records fetched |2021-04-26 12:52:02|
#  [DB]  Knowledge Graph Built: twitter [159/496] |2021-04-26 12:52:07|
#  [WIKIDATA]  Generating query with:types |2021-04-26 12:52:07|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:52:09|
#  [WIKIDATA]  Generating query with:parsing |2021-04-26 12:52:09|
#  [WIKIDATA]  5 records fetched |2021-04-26 12:52:10|
#  [DB]  Knowledge Graph Built: parsing [160/496] |2021-04-26 12:52:15|
#  [WIKIDATA]  Generating query with:strings |2021-04-26 12:52:15|
#  [WIKIDATA]  38 records fetched |2021-04-26 12:52:17|
#  [DB]  Knowledge Graph Built: strings [161/496] |2021-04-26 12:52:23|
#  [WIKIDATA]  Generating query with:automation |2021-04-26 12:52:23|
#  [WIKIDATA]  10 records fetched |2021-04-26 12:52:24|
#  [DB]  Knowledge Graph Built: automation [162/496] |2021-04-26 12:52:29|
#  [WIKIDATA]  Generating query with:audio |2021-04-26 12:52:29|
#  [WIKIDATA]  30 records fetched |2021-04-26 12:52:31|
#  [DB]  Knowledge Graph Built: audio [163/496] |2021-04-26 12:52:36|
#  [WIKIDATA]  Generating query with:gui |2021-04-26 12:52:36|
#  [WIKIDATA]  2 records fetched |2021-04-26 12:52:38|
#  [DB]  Knowledge Graph Built: gui [164/496] |2021-04-26 12:52:43|
#  [WIKIDATA]  Generating query with:100daysofcloud |2021-04-26 12:52:43|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:52:44|
#  [WIKIDATA]  Generating query with:wordpress |2021-04-26 12:52:44|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:52:45|
#  [WIKIDATA]  Generating query with:archlinux |2021-04-26 12:52:45|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:52:46|
#  [WIKIDATA]  Generating query with:tricks |2021-04-26 12:52:46|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:52:48|
#  [WIKIDATA]  Generating query with:tensorflow |2021-04-26 12:52:48|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:52:49|
#  [WIKIDATA]  Generating query with:tensorflowjs |2021-04-26 12:52:49|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:52:50|
#  [WIKIDATA]  Generating query with:satirejs |2021-04-26 12:52:50|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:52:51|
#  [WIKIDATA]  Generating query with:cookies |2021-04-26 12:52:51|
#  [WIKIDATA]  3 records fetched |2021-04-26 12:52:53|
#  [DB]  Knowledge Graph Built: cookies [165/496] |2021-04-26 12:52:58|
#  [WIKIDATA]  Generating query with:tcp |2021-04-26 12:52:58|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:52:59|
#  [WIKIDATA]  Generating query with:jobsearch |2021-04-26 12:52:59|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:53:00|
#  [WIKIDATA]  Generating query with:piral |2021-04-26 12:53:00|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:53:02|
#  [WIKIDATA]  Generating query with:rest |2021-04-26 12:53:02|
#  [WIKIDATA]  83 records fetched |2021-04-26 12:53:04|
#  [DB]  Knowledge Graph Built: rest [166/496] |2021-04-26 12:53:10|
#  [WIKIDATA]  Generating query with:firefox |2021-04-26 12:53:10|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:53:11|
#  [WIKIDATA]  Generating query with:browser |2021-04-26 12:53:11|
#  [WIKIDATA]  26 records fetched |2021-04-26 12:53:13|
#  [DB]  Knowledge Graph Built: browser [167/496] |2021-04-26 12:53:19|
#  [WIKIDATA]  Generating query with:reactrouter |2021-04-26 12:53:19|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:53:20|
#  [WIKIDATA]  Generating query with:dataviz |2021-04-26 12:53:20|
#  [WIKIDATA]  44 records fetched |2021-04-26 12:53:22|
#  [DB]  Knowledge Graph Built: dataviz [168/496] |2021-04-26 12:53:27|
#  [WIKIDATA]  Generating query with:blm |2021-04-26 12:53:27|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:53:29|
#  [WIKIDATA]  Generating query with:racism |2021-04-26 12:53:29|
#  [WIKIDATA]  10 records fetched |2021-04-26 12:53:30|
#  [DB]  Knowledge Graph Built: racism [169/496] |2021-04-26 12:53:35|
#  [WIKIDATA]  Generating query with:words |2021-04-26 12:53:35|
#  [WIKIDATA]  70 records fetched |2021-04-26 12:53:38|
#  [DB]  Knowledge Graph Built: words [170/496] |2021-04-26 12:53:44|
#  [WIKIDATA]  Generating query with:stats |2021-04-26 12:53:44|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:53:45|
#  [WIKIDATA]  Generating query with:statemachine |2021-04-26 12:53:45|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:53:46|
#  [WIKIDATA]  Generating query with:state |2021-04-26 12:53:46|
#  [WIKIDATA]  203 records fetched |2021-04-26 12:53:51|
#  [DB]  Knowledge Graph Built: state [171/496] |2021-04-26 12:53:59|
#  [WIKIDATA]  Generating query with:reactnavigation |2021-04-26 12:53:59|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:54:00|
#  [WIKIDATA]  Generating query with:lgbtq |2021-04-26 12:54:00|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:54:02|
#  [WIKIDATA]  Generating query with:trans |2021-04-26 12:54:02|
#  [WIKIDATA]  43 records fetched |2021-04-26 12:54:04|
#  [DB]  Knowledge Graph Built: trans [172/496] |2021-04-26 12:54:09|
#  [WIKIDATA]  Generating query with:seo |2021-04-26 12:54:09|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:54:11|
#  [WIKIDATA]  Generating query with:web |2021-04-26 12:54:11|
#  [WIKIDATA]  87 records fetched |2021-04-26 12:54:13|
#  [DB]  Knowledge Graph Built: web [173/496] |2021-04-26 12:54:19|
#  [WIKIDATA]  Generating query with:discord |2021-04-26 12:54:19|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:54:21|
#  [WIKIDATA]  Generating query with:social |2021-04-26 12:54:21|
#  [WIKIDATA]  39 records fetched |2021-04-26 12:54:23|
#  [DB]  Knowledge Graph Built: social [174/496] |2021-04-26 12:54:28|
#  [WIKIDATA]  Generating query with:firebase |2021-04-26 12:54:28|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:54:30|
#  [WIKIDATA]  Generating query with:windows |2021-04-26 12:54:30|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:54:31|
#  [WIKIDATA]  Generating query with:wsl |2021-04-26 12:54:31|
#  [WIKIDATA]  13 records fetched |2021-04-26 12:54:32|
#  [DB]  Knowledge Graph Built: wsl [175/496] |2021-04-26 12:54:37|
#  [WIKIDATA]  Generating query with:dart |2021-04-26 12:54:37|
#  [WIKIDATA]  23 records fetched |2021-04-26 12:54:39|
#  [DB]  Knowledge Graph Built: dart [176/496] |2021-04-26 12:54:44|
#  [WIKIDATA]  Generating query with:flutter |2021-04-26 12:54:44|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:54:46|
#  [WIKIDATA]  Generating query with:ffi |2021-04-26 12:54:46|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:54:47|
#  [WIKIDATA]  Generating query with:blacklivesmatter |2021-04-26 12:54:47|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:54:48|
#  [WIKIDATA]  Generating query with:dev |2021-04-26 12:54:48|
#  [WIKIDATA]  52 records fetched |2021-04-26 12:54:50|
#  [DB]  Knowledge Graph Built: dev [177/496] |2021-04-26 12:54:56|
#  [WIKIDATA]  Generating query with:code |2021-04-26 12:54:56|
#  [WIKIDATA]  39 records fetched |2021-04-26 12:54:59|
#  [DB]  Knowledge Graph Built: code [178/496] |2021-04-26 12:55:04|
#  [WIKIDATA]  Generating query with:themes |2021-04-26 12:55:04|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:05|
#  [WIKIDATA]  Generating query with:colors |2021-04-26 12:55:05|
#  [WIKIDATA]  27 records fetched |2021-04-26 12:55:09|
#  [DB]  Knowledge Graph Built: colors [179/496] |2021-04-26 12:55:14|
#  [WIKIDATA]  Generating query with:springboot |2021-04-26 12:55:14|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:15|
#  [WIKIDATA]  Generating query with:devgrad2020 |2021-04-26 12:55:15|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:17|
#  [WIKIDATA]  Generating query with:octograd2020 |2021-04-26 12:55:17|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:18|
#  [WIKIDATA]  Generating query with:bot |2021-04-26 12:55:18|
#  [WIKIDATA]  51 records fetched |2021-04-26 12:55:20|
#  [DB]  Knowledge Graph Built: bot [180/496] |2021-04-26 12:55:26|
#  [WIKIDATA]  Generating query with:linkedin |2021-04-26 12:55:26|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:28|
#  [WIKIDATA]  Generating query with:cs50 |2021-04-26 12:55:28|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:29|
#  [WIKIDATA]  Generating query with:cleancode |2021-04-26 12:55:29|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:30|
#  [WIKIDATA]  Generating query with:heroku |2021-04-26 12:55:30|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:31|
#  [WIKIDATA]  Generating query with:jenkins |2021-04-26 12:55:31|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:32|
#  [WIKIDATA]  Generating query with:chat |2021-04-26 12:55:32|
#  [WIKIDATA]  40 records fetched |2021-04-26 12:55:34|
#  [DB]  Knowledge Graph Built: chat [181/496] |2021-04-26 12:55:40|
#  [WIKIDATA]  Generating query with:ageofempires |2021-04-26 12:55:40|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:41|
#  [WIKIDATA]  Generating query with:cv |2021-04-26 12:55:41|
#  [WIKIDATA]  138 records fetched |2021-04-26 12:55:44|
#  [DB]  Knowledge Graph Built: cv [182/496] |2021-04-26 12:55:51|
#  [WIKIDATA]  Generating query with:elixir |2021-04-26 12:55:51|
#  [WIKIDATA]  6 records fetched |2021-04-26 12:55:53|
#  [DB]  Knowledge Graph Built: elixir [183/496] |2021-04-26 12:55:58|
#  [WIKIDATA]  Generating query with:streaming |2021-04-26 12:55:58|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:55:59|
#  [WIKIDATA]  Generating query with:inclusion |2021-04-26 12:55:59|
#  [WIKIDATA]  92 records fetched |2021-04-26 12:56:02|
#  [DB]  Knowledge Graph Built: inclusion [184/496] |2021-04-26 12:56:08|
#  [WIKIDATA]  Generating query with:optimized |2021-04-26 12:56:08|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:56:10|
#  [WIKIDATA]  Generating query with:elm |2021-04-26 12:56:10|
#  [WIKIDATA]  5 records fetched |2021-04-26 12:56:11|
#  [DB]  Knowledge Graph Built: elm [185/496] |2021-04-26 12:56:16|
#  [WIKIDATA]  Generating query with:nextcloud |2021-04-26 12:56:16|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:56:17|
#  [WIKIDATA]  Generating query with:raspberrypi |2021-04-26 12:56:17|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:56:19|
#  [WIKIDATA]  Generating query with:distributedsystems |2021-04-26 12:56:19|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:56:20|
#  [WIKIDATA]  Generating query with:rails |2021-04-26 12:56:20|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:56:21|
#  [WIKIDATA]  Generating query with:ruby |2021-04-26 12:56:21|
#  [WIKIDATA]  56 records fetched |2021-04-26 12:56:23|
#  [DB]  Knowledge Graph Built: ruby [186/496] |2021-04-26 12:56:29|
#  [WIKIDATA]  Generating query with:cssgrid |2021-04-26 12:56:29|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:56:30|
#  [WIKIDATA]  Generating query with:grid |2021-04-26 12:56:30|
#  [WIKIDATA]  10 records fetched |2021-04-26 12:56:32|
#  [DB]  Knowledge Graph Built: grid [187/496] |2021-04-26 12:56:37|
#  [WIKIDATA]  Generating query with:selfimprovement |2021-04-26 12:56:37|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:56:38|
#  [WIKIDATA]  Generating query with:creativity |2021-04-26 12:56:38|
#  [WIKIDATA]  35 records fetched |2021-04-26 12:56:40|
#  [DB]  Knowledge Graph Built: creativity [188/496] |2021-04-26 12:56:46|
#  [WIKIDATA]  Generating query with:mindset |2021-04-26 12:56:46|
#  [WIKIDATA]  14 records fetched |2021-04-26 12:56:47|
#  [DB]  Knowledge Graph Built: mindset [189/496] |2021-04-26 12:56:52|
#  [WIKIDATA]  Generating query with:culture |2021-04-26 12:56:52|
#  [WIKIDATA]  50 records fetched |2021-04-26 12:56:55|
#  [DB]  Knowledge Graph Built: culture [190/496] |2021-04-26 12:57:01|
#  [WIKIDATA]  Generating query with:triplebyte |2021-04-26 12:57:01|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:02|
#  [WIKIDATA]  Generating query with:flexbox |2021-04-26 12:57:02|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:03|
#  [WIKIDATA]  Generating query with:twilio |2021-04-26 12:57:03|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:04|
#  [WIKIDATA]  Generating query with:typegraphql |2021-04-26 12:57:05|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:07|
#  [WIKIDATA]  Generating query with:kafka |2021-04-26 12:57:07|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:08|
#  [WIKIDATA]  Generating query with:ecommerce |2021-04-26 12:57:08|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:09|
#  [WIKIDATA]  Generating query with:carousel |2021-04-26 12:57:09|
#  [WIKIDATA]  15 records fetched |2021-04-26 12:57:10|
#  [DB]  Knowledge Graph Built: carousel [191/496] |2021-04-26 12:57:16|
#  [WIKIDATA]  Generating query with:advice |2021-04-26 12:57:16|
#  [WIKIDATA]  17 records fetched |2021-04-26 12:57:17|
#  [DB]  Knowledge Graph Built: advice [192/496] |2021-04-26 12:57:22|
#  [WIKIDATA]  Generating query with:autogenerate |2021-04-26 12:57:22|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:24|
#  [WIKIDATA]  Generating query with:browsers |2021-04-26 12:57:24|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:27|
#  [WIKIDATA]  Generating query with:documentation |2021-04-26 12:57:27|
#  [WIKIDATA]  71 records fetched |2021-04-26 12:57:30|
#  [DB]  Knowledge Graph Built: documentation [193/496] |2021-04-26 12:57:36|
#  [WIKIDATA]  Generating query with:devrel |2021-04-26 12:57:36|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:37|
#  [WIKIDATA]  Generating query with:developerexperience |2021-04-26 12:57:37|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:38|
#  [WIKIDATA]  Generating query with:developerrelations |2021-04-26 12:57:38|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:39|
#  [WIKIDATA]  Generating query with:messagebroker |2021-04-26 12:57:39|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:40|
#  [WIKIDATA]  Generating query with:nextauth |2021-04-26 12:57:40|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:42|
#  [WIKIDATA]  Generating query with:inclusive |2021-04-26 12:57:42|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:43|
#  [WIKIDATA]  Generating query with:bestpractices |2021-04-26 12:57:43|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:44|
#  [WIKIDATA]  Generating query with:communication |2021-04-26 12:57:44|
#  [WIKIDATA]  51 records fetched |2021-04-26 12:57:46|
#  [DB]  Knowledge Graph Built: communication [194/496] |2021-04-26 12:57:52|
#  [WIKIDATA]  Generating query with:recaptcha |2021-04-26 12:57:52|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:53|
#  [WIKIDATA]  Generating query with:hcaptcha |2021-04-26 12:57:53|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:57:54|
#  [WIKIDATA]  Generating query with:spam |2021-04-26 12:57:54|
#  [WIKIDATA]  16 records fetched |2021-04-26 12:57:56|
#  [DB]  Knowledge Graph Built: spam [195/496] |2021-04-26 12:58:01|
#  [WIKIDATA]  Generating query with:sre |2021-04-26 12:58:01|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:58:02|
#  [WIKIDATA]  Generating query with:scrape |2021-04-26 12:58:02|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:58:04|
#  [WIKIDATA]  Generating query with:data |2021-04-26 12:58:04|
#  [WIKIDATA]  47 records fetched |2021-04-26 12:58:06|
#  [DB]  Knowledge Graph Built: data [196/496] |2021-04-26 12:58:12|
#  [WIKIDATA]  Generating query with:selfhosted |2021-04-26 12:58:12|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:58:13|
#  [WIKIDATA]  Generating query with:stripe |2021-04-26 12:58:13|
#  [WIKIDATA]  2 records fetched |2021-04-26 12:58:14|
#  [DB]  Knowledge Graph Built: stripe [197/496] |2021-04-26 12:58:19|
#  [WIKIDATA]  Generating query with:jiraclone |2021-04-26 12:58:19|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:58:20|
#  [WIKIDATA]  Generating query with:akita |2021-04-26 12:58:20|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:58:22|
#  [WIKIDATA]  Generating query with:habits |2021-04-26 12:58:22|
#  [WIKIDATA]  26 records fetched |2021-04-26 12:58:23|
#  [DB]  Knowledge Graph Built: habits [198/496] |2021-04-26 12:58:29|
#  [WIKIDATA]  Generating query with:todayisearched |2021-04-26 12:58:29|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:58:30|
#  [WIKIDATA]  Generating query with:caching |2021-04-26 12:58:30|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:58:31|
#  [WIKIDATA]  Generating query with:googlefonts |2021-04-26 12:58:31|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:58:33|
#  [WIKIDATA]  Generating query with:relay |2021-04-26 12:58:33|
#  [WIKIDATA]  11 records fetched |2021-04-26 12:58:34|
#  [DB]  Knowledge Graph Built: relay [199/496] |2021-04-26 12:58:39|
#  [WIKIDATA]  Generating query with:docs |2021-04-26 12:58:39|
#  [WIKIDATA]  51 records fetched |2021-04-26 12:58:41|
#  [DB]  Knowledge Graph Built: docs [200/496] |2021-04-26 12:58:47|
#  [WIKIDATA]  Generating query with:opencollective |2021-04-26 12:58:47|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:58:49|
#  [WIKIDATA]  Generating query with:codefund |2021-04-26 12:58:49|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:58:50|
#  [WIKIDATA]  Generating query with:scarf |2021-04-26 12:58:50|
#  [WIKIDATA]  8 records fetched |2021-04-26 12:58:51|
#  [DB]  Knowledge Graph Built: scarf [201/496] |2021-04-26 12:58:56|
#  [WIKIDATA]  Generating query with:gitlab |2021-04-26 12:58:56|
#  [WIKIDATA]  13 records fetched |2021-04-26 12:58:58|
#  [DB]  Knowledge Graph Built: gitlab [202/496] |2021-04-26 12:59:03|
#  [WIKIDATA]  Generating query with:https |2021-04-26 12:59:03|
#  [WIKIDATA]  11 records fetched |2021-04-26 12:59:05|
#  [DB]  Knowledge Graph Built: https [203/496] |2021-04-26 12:59:10|
#  [WIKIDATA]  Generating query with:ssl |2021-04-26 12:59:10|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:59:11|
#  [WIKIDATA]  Generating query with:adonis |2021-04-26 12:59:11|
#  [WIKIDATA]  15 records fetched |2021-04-26 12:59:13|
#  [DB]  Knowledge Graph Built: adonis [204/496] |2021-04-26 12:59:18|
#  [WIKIDATA]  Generating query with:apollo |2021-04-26 12:59:18|
#  [WIKIDATA]  5 records fetched |2021-04-26 12:59:20|
#  [DB]  Knowledge Graph Built: apollo [205/496] |2021-04-26 12:59:25|
#  [WIKIDATA]  Generating query with:elasticsearch |2021-04-26 12:59:25|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:59:26|
#  [WIKIDATA]  Generating query with:dom |2021-04-26 12:59:26|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:59:27|
#  [WIKIDATA]  Generating query with:width |2021-04-26 12:59:27|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:59:28|
#  [WIKIDATA]  Generating query with:lazyload |2021-04-26 12:59:28|
#  [WIKIDATA]  0 records fetched |2021-04-26 12:59:30|
#  [WIKIDATA]  Generating query with:money |2021-04-26 12:59:30|
#  [WIKIDATA]  Query failed: |2021-04-26 13:00:32|
#  [WIKIDATA]  Generating query with:softskills |2021-04-26 13:00:32|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:00:33|
#  [WIKIDATA]  Generating query with:stimulus |2021-04-26 13:00:33|
#  [WIKIDATA]  20 records fetched |2021-04-26 13:00:35|
#  [DB]  Knowledge Graph Built: stimulus [206/496] |2021-04-26 13:00:40|
#  [WIKIDATA]  Generating query with:setup |2021-04-26 13:00:40|
#  [WIKIDATA]  11 records fetched |2021-04-26 13:00:41|
#  [DB]  Knowledge Graph Built: setup [207/496] |2021-04-26 13:00:47|
#  [WIKIDATA]  Generating query with:efficiency |2021-04-26 13:00:47|
#  [WIKIDATA]  43 records fetched |2021-04-26 13:00:49|
#  [DB]  Knowledge Graph Built: efficiency [208/496] |2021-04-26 13:00:54|
#  [WIKIDATA]  Generating query with:containers |2021-04-26 13:00:54|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:00:55|
#  [WIKIDATA]  Generating query with:emoji |2021-04-26 13:00:55|
#  [WIKIDATA]  41 records fetched |2021-04-26 13:00:58|
#  [DB]  Knowledge Graph Built: emoji [209/496] |2021-04-26 13:01:04|
#  [WIKIDATA]  Generating query with:youtubechannels |2021-04-26 13:01:04|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:01:05|
#  [WIKIDATA]  Generating query with:tooltip |2021-04-26 13:01:05|
#  [WIKIDATA]  5 records fetched |2021-04-26 13:01:06|
#  [DB]  Knowledge Graph Built: tooltip [210/496] |2021-04-26 13:01:11|
#  [WIKIDATA]  Generating query with:leadership |2021-04-26 13:01:11|
#  [WIKIDATA]  11 records fetched |2021-04-26 13:01:13|
#  [DB]  Knowledge Graph Built: leadership [211/496] |2021-04-26 13:01:18|
#  [WIKIDATA]  Generating query with:versioncontrol |2021-04-26 13:01:18|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:01:19|
#  [WIKIDATA]  Generating query with:socket |2021-04-26 13:01:19|
#  [WIKIDATA]  20 records fetched |2021-04-26 13:01:21|
#  [DB]  Knowledge Graph Built: socket [212/496] |2021-04-26 13:01:26|
#  [WIKIDATA]  Generating query with:timemanagement |2021-04-26 13:01:26|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:01:28|
#  [WIKIDATA]  Generating query with:pipedream |2021-04-26 13:01:28|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:01:29|
#  [WIKIDATA]  Generating query with:patterns |2021-04-26 13:01:29|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:01:30|
#  [WIKIDATA]  Generating query with:blogging |2021-04-26 13:01:30|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:01:31|
#  [WIKIDATA]  Generating query with:expo |2021-04-26 13:01:31|
#  [WIKIDATA]  10 records fetched |2021-04-26 13:01:32|
#  [DB]  Knowledge Graph Built: expo [213/496] |2021-04-26 13:01:38|
#  [WIKIDATA]  Generating query with:news |2021-04-26 13:01:38|
#  [WIKIDATA]  21 records fetched |2021-04-26 13:01:39|
#  [DB]  Knowledge Graph Built: news [214/496] |2021-04-26 13:01:45|
#  [WIKIDATA]  Generating query with:techtalks |2021-04-26 13:01:45|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:01:46|
#  [WIKIDATA]  Generating query with:sql |2021-04-26 13:01:46|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:01:47|
#  [WIKIDATA]  Generating query with:postman |2021-04-26 13:01:47|
#  [WIKIDATA]  Query failed: |2021-04-26 13:02:49|
#  [WIKIDATA]  Generating query with:recoil |2021-04-26 13:02:49|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:02:50|
#  [WIKIDATA]  Generating query with:workflow |2021-04-26 13:02:50|
#  [WIKIDATA]  Query failed: |2021-04-26 13:03:52|
#  [WIKIDATA]  Generating query with:preview |2021-04-26 13:03:52|
#  [WIKIDATA]  40 records fetched |2021-04-26 13:03:54|
#  [DB]  Knowledge Graph Built: preview [215/496] |2021-04-26 13:04:00|
#  [WIKIDATA]  Generating query with:unix |2021-04-26 13:04:00|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:04:01|
#  [WIKIDATA]  Generating query with:awscertified |2021-04-26 13:04:01|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:04:02|
#  [WIKIDATA]  Generating query with:pragmatic |2021-04-26 13:04:02|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:04:03|
#  [WIKIDATA]  Generating query with:appdevelopment |2021-04-26 13:04:03|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:04:04|
#  [WIKIDATA]  Generating query with:jupyter |2021-04-26 13:04:04|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:04:06|
#  [WIKIDATA]  Generating query with:students |2021-04-26 13:04:06|
#  [WIKIDATA]  58 records fetched |2021-04-26 13:04:08|
#  [DB]  Knowledge Graph Built: students [216/496] |2021-04-26 13:04:13|
#  [WIKIDATA]  Generating query with:community |2021-04-26 13:04:13|
#  [WIKIDATA]  126 records fetched |2021-04-26 13:04:16|
#  [DB]  Knowledge Graph Built: community [217/496] |2021-04-26 13:04:23|
#  [WIKIDATA]  Generating query with:ionic |2021-04-26 13:04:23|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:04:24|
#  [WIKIDATA]  Generating query with:thesideprojectideas |2021-04-26 13:04:24|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:04:25|
#  [WIKIDATA]  Generating query with:macbook |2021-04-26 13:04:25|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:04:26|
#  [WIKIDATA]  Generating query with:growth |2021-04-26 13:04:26|
#  [WIKIDATA]  64 records fetched |2021-04-26 13:04:29|
#  [DB]  Knowledge Graph Built: growth [218/496] |2021-04-26 13:04:35|
#  [WIKIDATA]  Generating query with:kotlin |2021-04-26 13:04:35|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:04:36|
#  [WIKIDATA]  Generating query with:video |2021-04-26 13:04:36|
#  [WIKIDATA]  149 records fetched |2021-04-26 13:04:39|
#  [DB]  Knowledge Graph Built: video [219/496] |2021-04-26 13:04:46|
#  [WIKIDATA]  Generating query with:wasp |2021-04-26 13:04:46|
#  [WIKIDATA]  8 records fetched |2021-04-26 13:04:47|
#  [DB]  Knowledge Graph Built: wasp [220/496] |2021-04-26 13:04:52|
#  [WIKIDATA]  Generating query with:macos |2021-04-26 13:04:52|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:04:53|
#  [WIKIDATA]  Generating query with:publishing |2021-04-26 13:04:53|
#  [WIKIDATA]  62 records fetched |2021-04-26 13:04:56|
#  [DB]  Knowledge Graph Built: publishing [221/496] |2021-04-26 13:05:02|
#  [WIKIDATA]  Generating query with:bootcamp |2021-04-26 13:05:02|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:05:03|
#  [WIKIDATA]  Generating query with:devtools |2021-04-26 13:05:03|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:05:04|
#  [WIKIDATA]  Generating query with:firstpost |2021-04-26 13:05:04|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:05:05|
#  [WIKIDATA]  Generating query with:changelog |2021-04-26 13:05:05|
#  [WIKIDATA]  1 records fetched |2021-04-26 13:05:07|
#  [DB]  Knowledge Graph Built: changelog [222/496] |2021-04-26 13:05:12|
#  [WIKIDATA]  Generating query with:newsletter |2021-04-26 13:05:12|
#  [WIKIDATA]  41 records fetched |2021-04-26 13:05:14|
#  [DB]  Knowledge Graph Built: newsletter [223/496] |2021-04-26 13:05:19|
#  [WIKIDATA]  Generating query with:email |2021-04-26 13:05:19|
#  [WIKIDATA]  40 records fetched |2021-04-26 13:05:21|
#  [DB]  Knowledge Graph Built: email [224/496] |2021-04-26 13:05:27|
#  [WIKIDATA]  Generating query with:libraries |2021-04-26 13:05:27|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:05:28|
#  [WIKIDATA]  Generating query with:agile |2021-04-26 13:05:28|
#  [WIKIDATA]  21 records fetched |2021-04-26 13:05:30|
#  [DB]  Knowledge Graph Built: agile [225/496] |2021-04-26 13:05:35|
#  [WIKIDATA]  Generating query with:datastructure |2021-04-26 13:05:35|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:05:36|
#  [WIKIDATA]  Generating query with:assault |2021-04-26 13:05:36|
#  [WIKIDATA]  17 records fetched |2021-04-26 13:05:38|
#  [DB]  Knowledge Graph Built: assault [226/496] |2021-04-26 13:05:43|
#  [WIKIDATA]  Generating query with:harassment |2021-04-26 13:05:43|
#  [WIKIDATA]  5 records fetched |2021-04-26 13:05:45|
#  [DB]  Knowledge Graph Built: harassment [227/496] |2021-04-26 13:05:50|
#  [WIKIDATA]  Generating query with:misconduct |2021-04-26 13:05:50|
#  [WIKIDATA]  28 records fetched |2021-04-26 13:05:52|
#  [DB]  Knowledge Graph Built: misconduct [228/496] |2021-04-26 13:05:57|
#  [WIKIDATA]  Generating query with:sexism |2021-04-26 13:05:57|
#  [WIKIDATA]  13 records fetched |2021-04-26 13:05:59|
#  [DB]  Knowledge Graph Built: sexism [229/496] |2021-04-26 13:06:04|
#  [WIKIDATA]  Generating query with:zsh |2021-04-26 13:06:04|
#  [WIKIDATA]  23 records fetched |2021-04-26 13:06:06|
#  [DB]  Knowledge Graph Built: zsh [230/496] |2021-04-26 13:06:11|
#  [WIKIDATA]  Generating query with:competitiveprogramming |2021-04-26 13:06:11|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:12|
#  [WIKIDATA]  Generating query with:datastructures |2021-04-26 13:06:12|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:13|
#  [WIKIDATA]  Generating query with:ngrok |2021-04-26 13:06:13|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:15|
#  [WIKIDATA]  Generating query with:senior |2021-04-26 13:06:15|
#  [WIKIDATA]  59 records fetched |2021-04-26 13:06:17|
#  [DB]  Knowledge Graph Built: senior [231/496] |2021-04-26 13:06:23|
#  [WIKIDATA]  Generating query with:autism |2021-04-26 13:06:23|
#  [WIKIDATA]  42 records fetched |2021-04-26 13:06:25|
#  [DB]  Knowledge Graph Built: autism [232/496] |2021-04-26 13:06:31|
#  [WIKIDATA]  Generating query with:aspergers |2021-04-26 13:06:31|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:32|
#  [WIKIDATA]  Generating query with:certification |2021-04-26 13:06:32|
#  [WIKIDATA]  54 records fetched |2021-04-26 13:06:34|
#  [DB]  Knowledge Graph Built: certification [233/496] |2021-04-26 13:06:40|
#  [WIKIDATA]  Generating query with:form |2021-04-26 13:06:40|
#  [WIKIDATA]  164 records fetched |2021-04-26 13:06:43|
#  [DB]  Knowledge Graph Built: form [234/496] |2021-04-26 13:06:50|
#  [WIKIDATA]  Generating query with:projectmanagement |2021-04-26 13:06:50|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:51|
#  [WIKIDATA]  Generating query with:scrolltotext |2021-04-26 13:06:51|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:53|
#  [WIKIDATA]  Generating query with:softwaredevelopment |2021-04-26 13:06:53|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:54|
#  [WIKIDATA]  Generating query with:juniordev |2021-04-26 13:06:54|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:55|
#  [WIKIDATA]  Generating query with:wardleymaps |2021-04-26 13:06:55|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:56|
#  [WIKIDATA]  Generating query with:githubactions |2021-04-26 13:06:56|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:58|
#  [WIKIDATA]  Generating query with:environmentvariables |2021-04-26 13:06:58|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:06:59|
#  [WIKIDATA]  Generating query with:zeit |2021-04-26 13:06:59|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:07:00|
#  [WIKIDATA]  Generating query with:deploy |2021-04-26 13:07:00|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:07:01|
#  [WIKIDATA]  Generating query with:githubpages |2021-04-26 13:07:01|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:07:02|
#  [WIKIDATA]  Generating query with:chrome |2021-04-26 13:07:02|
#  [WIKIDATA]  19 records fetched |2021-04-26 13:07:04|
#  [DB]  Knowledge Graph Built: chrome [235/496] |2021-04-26 13:07:09|
#  [WIKIDATA]  Generating query with:visualization |2021-04-26 13:07:09|
#  [WIKIDATA]  51 records fetched |2021-04-26 13:07:11|
#  [DB]  Knowledge Graph Built: visualization [236/496] |2021-04-26 13:07:17|
#  [WIKIDATA]  Generating query with:clojure |2021-04-26 13:07:17|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:07:18|
#  [WIKIDATA]  Generating query with:junior |2021-04-26 13:07:18|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:07:19|
#  [WIKIDATA]  Generating query with:educational |2021-04-26 13:07:19|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:07:21|
#  [WIKIDATA]  Generating query with:jobs |2021-04-26 13:07:21|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:07:22|
#  [WIKIDATA]  Generating query with:mercadopago |2021-04-26 13:07:22|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:07:23|
#  [WIKIDATA]  Generating query with:spanish |2021-04-26 13:07:23|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:07:25|
#  [WIKIDATA]  Generating query with:poll |2021-04-26 13:07:25|
#  [WIKIDATA]  36 records fetched |2021-04-26 13:07:27|
#  [DB]  Knowledge Graph Built: poll [237/496] |2021-04-26 13:07:32|
#  [WIKIDATA]  Generating query with:async |2021-04-26 13:07:32|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:07:33|
#  [WIKIDATA]  Generating query with:personal |2021-04-26 13:07:33|
#  [WIKIDATA]  3 records fetched |2021-04-26 13:07:35|
#  [DB]  Knowledge Graph Built: personal [238/496] |2021-04-26 13:07:40|
#  [WIKIDATA]  Generating query with:website |2021-04-26 13:07:40|
#  [WIKIDATA]  Query failed: |2021-04-26 13:08:42|
#  [WIKIDATA]  Generating query with:wysiwyg |2021-04-26 13:08:42|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:08:43|
#  [WIKIDATA]  Generating query with:tinymce |2021-04-26 13:08:43|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:08:44|
#  [WIKIDATA]  Generating query with:domain |2021-04-26 13:08:44|
#  [WIKIDATA]  Query failed: |2021-04-26 13:09:46|
#  [WIKIDATA]  Generating query with:haskell |2021-04-26 13:09:46|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:09:47|
#  [WIKIDATA]  Generating query with:smalltalk |2021-04-26 13:09:47|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:09:48|
#  [WIKIDATA]  Generating query with:pizzly |2021-04-26 13:09:48|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:09:49|
#  [WIKIDATA]  Generating query with:algorithm |2021-04-26 13:09:49|
#  [WIKIDATA]  1420 records fetched |2021-04-26 13:09:56|
#  [DB]  Knowledge Graph Built: algorithm [239/496] |2021-04-26 13:10:18|
#  [WIKIDATA]  Generating query with:inthirtyseconds |2021-04-26 13:10:18|
#  [WIKIDATA]  0 records fetched |2021-04-26 13:10:20|
